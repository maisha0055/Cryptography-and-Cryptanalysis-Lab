# %%
#install-PyCryptodome
#to do
# !pip install pycryptodome
# Out:
# Requirement already satisfied: pycryptodome in /usr/local/lib/python3.12/dist-packages (3.23.0)

# %%
from Crypto.Cipher import DES
from Crypto.Random import get_random_bytes

# %%
def pad_text(text):
    # Ensure the plaintext length is a multiple of 8 bytes (DES block size)
    #generate and return the padded_text
    padding_length = 8 - (len(text) % 8)
    padding = bytes([padding_length] * padding_length)
    padded_text = text + padding
    return padded_text

# %%
def unpad_text(padded_text):
    # Remove the padding bytes to get the original plaintext
    #to do
    padding_length = padded_text[-1]
    unpadded_text = padded_text[:-padding_length]
    return unpadded_text

# %%
def des_encrypt(plaintext, key):
    #encrypt DES(Mode:ECB) and return the ciphertext
    cipher = DES.new(key, DES.MODE_ECB)
    ciphertext = cipher.encrypt(plaintext)
    return ciphertext

# %%
plaintext = b"This is a secret text"
# Generate a random 64-bit (8-byte) key
#to do
key = get_random_bytes(8)

print("Original plaintext:", plaintext.decode('utf-8'))
print("Original key (in bytes):", key)

plaintext = pad_text(plaintext)

ciphertext = des_encrypt(plaintext, key)
print("Encrypted ciphertext (in bytes):", ciphertext)
# Out:
# Original plaintext: This is a secret text
# Original key (in bytes): b'f\xf6\xd7\x92,\x96J\xa7'
# Encrypted ciphertext (in bytes): b'\x93\x93\x89>o\x11\xc9\xcb\xfbx\xc61\x8b\xd2\xe7e\xfc-V\xd2z\xdb\xf9\t'

# %%
def des_decrypt(ciphertext, key):
    #decrypt DES(Mode:ECB) and return the plaintext
    cipher = DES.new(key, DES.MODE_ECB)
    plaintext = cipher.decrypt(ciphertext)
    return plaintext

# %%
# Replace these with your ciphertext and key
ciphertext = b'\x93\x93\x89>o\x11\xc9\xcb\xfbx\xc61\x8b\xd2\xe7e\xfc-V\xd2z\xdb\xf9\t'
key = b'f\xf6\xd7\x92,\x96J\xa7'

decrypted_text = des_decrypt(ciphertext, key)
original_text = unpad_text(decrypted_text)

print("Decrypted text:", original_text.decode('utf-8'))
# Out:
# Decrypted text: This is a secret text

# %%
#Implement Double DES and check if your ciphertext matches the provided output.
plaintext = b"I am Batman"
KeyA = b'\x01\xadWR\xeb\x1a\xa2\x86'
KeyB = b'\xf7\xcf\xd6r\xd9\xa1\x141'
Given_Output = b'\xd2Em\x06-1\xf7$\x0c\xaaI\xf0\xc3\x00\xbd}'

#to do
#Pad
plaintext_padded = pad_text(plaintext)

intermediate = des_encrypt(plaintext_padded, KeyA)

double_des_ciphertext = des_encrypt(intermediate, KeyB)

print("Your Output:", double_des_ciphertext)
print("Given Output:", Given_Output)
print("Match:", double_des_ciphertext == Given_Output)
# Out:
# Your Output: b'\xd2Em\x06-1\xf7$\x0c\xaaI\xf0\xc3\x00\xbd}'
# Given Output: b'\xd2Em\x06-1\xf7$\x0c\xaaI\xf0\xc3\x00\xbd}'
# Match: True

# %%
#Pattern Repetition in DES ECB Mode Ciphertext
plaintext = b"ABCDEFGHABCDEFGHABCDEFGH"
key = get_random_bytes(8)  # Generate a random 64-bit (8-byte) key

padtext = pad_text(plaintext)
c1 = des_encrypt(padtext,key)
print(c1)
# Out:
# b"\\\xcf\xe90\xbc\x8f\xa5\x12\\\xcf\xe90\xbc\x8f\xa5\x12\\\xcf\xe90\xbc\x8f\xa5\x12\x1f'\xed\xff\xe5\xcf\xf4\xbd"
